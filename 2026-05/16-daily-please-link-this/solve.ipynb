# %%
from pwn import ELF
elf = ELF('handout/chal')
# Out:
# [*] Checking for new versions of pwntools
#     To disable this functionality, set the contents of /home/node/.cache/.pwntools-cache-3.14/update to 'never' (old way).
#     Or add the following lines to ~/.pwn.conf or ~/.config/pwn.conf (or /etc/pwn.conf system-wide):
#         [update]
#         interval=never
# [*] You have the latest version of Pwntools (4.15.0)
# [*] '/workspaces/alpaca-ctf/2026-05/16-daily-please-link-this/handout/chal'
#     Arch:       amd64-64-little
#     RELRO:      Partial RELRO
#     Stack:      No canary found
#     NX:         NX enabled
#     PIE:        No PIE (0x400000)
#     SHSTK:      Enabled
#     IBT:        Enabled
#     Stripped:   No

# %%
(elf.got["puts"]-elf.symbols["values"])//8
# Out:
# -12

# %%
elf.symbols["system"]
# Out:
# 4198564
