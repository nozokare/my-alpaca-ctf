# %%
n = 
cs = [
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
]

# %%
import math
for c in cs:
    if math.gcd(n, c) != 1:
        print(math.gcd(n, c))

# %%
dic = {}
dic[cs[0]] = "A"
dic[cs[1]] = "l"
dic[cs[2]] = "p"
dic[cs[3]] = "a"
dic[cs[4]] = "c"
dic[cs[6]] = "{"
dic[cs[-1]] = "}"

print("".join(dic.get(c, "?") for c in cs))
# Out:
# Alpaca{????p????l??lp?c?????pl?c??}
