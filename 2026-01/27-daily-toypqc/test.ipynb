# %%
import os
from random import SystemRandom

FLAG = os.getenv("FLAG", "Alpaca{********dummy********}").encode()
assert FLAG.startswith(b"Alpaca{") and FLAG.endswith(b"}")
flag = FLAG[7:-1]
assert len(flag) == 21

n = 7
m = 10
p = 8380417
F = GF(p)

random = SystemRandom()

A = matrix(F, [[random.randrange(0, p) for _ in range(n)] for _ in range(m)])
s = vector(F, [int.from_bytes(flag[3 * i : 3 * (i + 1)], "big") for i in range(n)])
e = vector(F, [random.randrange(0, 2) for _ in range(m)])
b = A * s + e

print("A =", [v.list() for v in A])
print("b =", b.list())
# Out:
# A = [[572961, 3205748, 1217766, 2037489, 5002315, 1583815, 4950398], [2185540, 579083, 5339535, 4585770, 3749657, 182814, 4732713], [4961715, 4334372, 503838, 7549849, 6994825, 2290681, 1459020], [8365015, 6165701, 1518777, 5924928, 3809810, 7533534, 5844976], [2355143, 4765793, 680461, 1078820, 5795265, 6894215, 5811389], [4159448, 2313844, 5478629, 2041131, 3257023, 5212007, 1342272], [6167023, 986766, 7972607, 4956264, 2061882, 6905254, 1291014], [5833468, 8327262, 4074891, 7906328, 2673885, 345579, 4223540], [3433613, 6531131, 216637, 7848110, 3680130, 7077699, 3965112], [2330744, 5329491, 42090, 5008570, 7100305, 2845348, 997702]]
# b = [8283681, 6326670, 2070501, 1893232, 3380899, 4530064, 4337561, 7674349, 4088031, 7725313]

# %%
A
# Out:
# [ 572961 3205748 1217766 2037489 5002315 1583815 4950398]
# [2185540  579083 5339535 4585770 3749657  182814 4732713]
# [4961715 4334372  503838 7549849 6994825 2290681 1459020]
# [8365015 6165701 1518777 5924928 3809810 7533534 5844976]
# [2355143 4765793  680461 1078820 5795265 6894215 5811389]
# [4159448 2313844 5478629 2041131 3257023 5212007 1342272]
# [6167023  986766 7972607 4956264 2061882 6905254 1291014]
# [5833468 8327262 4074891 7906328 2673885  345579 4223540]
# [3433613 6531131  216637 7848110 3680130 7077699 3965112]
# [2330744 5329491   42090 5008570 7100305 2845348  997702]

# %%
float(2**(8*3)/p)
# Out:
# 2.0019547953282038

# %%
float(int.from_bytes(b"\x7f\x7f\x7f")/p)
# Out:
# 0.9970519366757048

# %%
int.from_bytes(b"\x7f\x7f\x7f")
# Out:
# 8355711
